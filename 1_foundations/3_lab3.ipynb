# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# galdrich@gmail.com
# www.linkedin.com/in/galdrich
# (LinkedIn)
# Top Skills
# Business Transformation
# Technology Roadmapping
# Solution Architecture
# Certifications
# ITIL Foundation Certified 3.0
# Past Certifications: CISSP, NSIAM,
# CCDA, CCNA, CCSE
# Machine Learning
# Digital Transformation
# Robotics: Aerial Robotics
# Publications
# InfoBlox 2013 Global Sales
# Conference Customer Keynote
# Telecommuting Has Come of Age
# Global GIS Conference (highest
# rated speaker)
# Keynote for Annual Medical
# Association Meeting
# Cisco Live Customer Panel
# Greg Aldrich
# Global CIO | Technology Executive | Aligning IT Strategy with
# Business Vision | Driving Digital Transformation & Organizational
# Excellence
# Colorado Springs, Colorado, United States
# Summary
# DESIGNING AND DELIVERING TECHNOLOGY SOLUTIONS THAT
# DRIVE ENTERPRISE SUCCESS
# As a global Technology Executive and Business Leader, I align
# risk management, security and IT initiatives with business goals to
# drive enterprise transformation, impacting multiple business lines
# worldwide.
# Through encouraging collaboration, trust and individual growth,
# I’ve competitively positioned startup, turnaround, and high growth
# environments.
# By implementing process reengineering, change management, and
# outsourcing and insourcing initiatives, I’ve fostered an environment
# of continuous improvement and best practices.
# My talent for leveraging technology vision and innovation has
# contributed to my success as an entrepreneurial leader, delivering
# enterprise-wide solutions and driving rapid growth.
# SPECIALTIES
# ♦  Technology Leadership
# ♦  Strategy Planning and Technology Roadmaps
# ♦  Business and Technology Alignment
# ♦  Best Practices and Process Re-engineering
# ♦  Multibillion Dollar M&As
# ♦  Organizational Development and Design
# ♦  Global IT Governance, Operations and Security
# ♦  Global IT Project / Program Management
# ♦  Business and IT Transformation
# ♦  Outsourcing and Backsourcing Initiatives
# ♦  Global Data Centers
#   Page 1 of 9
# ♦  Cloud Computing
# ♦  “Green” Technology Solutions
# Experience
# Andrew Wommack Ministries, Inc.
# Chief Information Officer
# August 2022 - Present (3 years 9 months)
# Woodland Park, Colorado, United States
# As the Chief Information Officer (CIO) for Andrew Wommack Ministries and
# Charis Bible College, I oversee global IT operations and strategy, ensuring our
# technology infrastructure and applications support and enhance our mission
# to spread the Gospel and educate future leaders. As a member of the senior
# leadership team, I collaborate closely with other executives to drive innovation,
# efficiency, and growth across our organization.
# Key Responsibilities
# * Lead the development and implementation of IT strategies that align with the
# ministry's mission and goals
# * Oversee global Information Technology, ensuring the reliability, security, and
# scalability of our systems
# * Collaborate with senior leadership to identify and execute technology-driven
# initiatives that enhance organizational effectiveness
# * Manage a diverse team of IT professionals, fostering a culture of excellence,
# collaboration, and continuous improvement
# * Drive digital transformation efforts to improve the user experience for our
# students, staff, and global audience
# * Ensure compliance with relevant regulations and industry standards,
# maintaining the highest levels of data security and privacy
# Continued Engagement:
# While dedicated to this mission, I continue to serve as a Senior Advisor
# for Blue Tree Technology Group and a Senior Transition Architect for SDS
# Consulting, leveraging my expertise to help drive IT strategy and innovation for
# key clients.
# Background:
# In 2024, I transitioned from a strategy advisor and virtual CIO to join
# Andrew Wommack Ministries and Charis Bible College, bringing with me a
#   Page 2 of 9
# wealth of experience in IT leadership and a passion for using technology
# to further Kingdom work. My ongoing role as a senior advisor for Blue Tree
# Technology Group allows me to stay connected to industry trends and
# innovations, ensuring that our ministry remains at the forefront of technological
# advancements.
# Blue Tree Technology Group
# 7 years 3 months
# Senior Strategy Advisor/vCIO
# January 2024 - Present (2 years 4 months)
# San Francisco Bay Area
# Part-time Senior Strategy Advisor and Virtual CIO for Blue Tree Technology
# Group (see below description)
# Senior Strategy Advisor/vCIO
# February 2019 - Present (7 years 3 months)
# San Francisco Bay Area
# Full-time Senior Strategy Advisor and Virtual CIO for Blue Tree Technology
# Group focused on solving business pain points caused by antiquated
# technology and processes. Advising C-level stakeholders on technology for
# business transformation, organizational agility, and innovation.
# The Blue Tree approach is holistic and strategic transformation. We address
# not only the technology but also the people and processes required to
# sustain effective management of the current and future state of our client
# organizations.
# SDS Consulting
# CIO – Executive Leadership – Senior Transition Architect
# November 2023 - Present (2 years 6 months)
# Newport Beach, California, United States
# As a Senior Transition Architect and CIO-level advisor, I help enterprises
# navigate complex technology and organizational transformations with clarity,
# confidence, and measurable outcomes. Within the consultancy, my role
# bridges executive vision and operational execution, ensuring that every
# transformation initiative aligns technology strategy with business purpose.
# In this capacity, I:
#   Page 3 of 9
# Architect transformation roadmaps that integrate cloud, data, and infrastructure
# modernization with people and process realignment.
# Lead C-suite advisory engagements, helping organizations design and
# execute strategic transitions—whether driven by mergers, modernization,
# regulatory shifts, or innovation goals.
# Translate business imperatives into actionable IT strategies, aligning
# stakeholders, budgets, and systems to deliver sustained value.
# Oversee governance, risk, and compliance during transition phases, ensuring
# security, continuity, and long-term resilience.
# Mentor client technology leaders, building internal capacity and leadership
# continuity beyond the engagement.
# Drive measurable transformation outcomes, from accelerated time-to-value to
# improved scalability, reliability, and business alignment.
# My focus is on turning disruption into opportunity—equipping organizations
# to thrive through change by uniting strategy, structure, and systems under a
# cohesive transformation framework.
# Nautilus Data Technologies
# Strategic Advisor
# July 2018 - April 2024 (5 years 10 months)
# San Francisco Bay Area
# Nautilus Data Technologies is pioneering a new generation of data centers
# by delivering innovative solutions that provide a strategic platform for greater
# customer success. We are focused on providing disruptive technologies
# and solutions addressing the emerging data center efficiency and security
# requirements in computing, business continuity and disaster recovery markets
# Maverick Gaming
# Director, Information Technology
# July 2020 - April 2021 (10 months)
# Washington, United States
# San Manuel Band of Mission Indians
# Chief Information Technology Officer
# 2014 - 2018 (4 years)
#   Page 4 of 9
# Highland, CA
# As Chief Information Technology Officer I provided the technology direction
# and oversight for the tribal government and the largest casino in California.
# Among a range of functions, I drove the transformation of the IT organization
# with a focus on improving operational efficiency. I worked closely with casino
# executives and tribal leaders to improve IT alignment and increase the velocity
# of technology projects. Additionally, I implemented IT Governance and made
# significant improvements to IT Service Management. I also spearheaded and
# successfully implemented enterprise collaboration to successfully tear down
# operational silos across departments.
# A few key achievements in this role include:
# ★ Successfully delivered multiple large-scale technology enhancements and
# improvements.
# ★ Upgraded the IT infrastructure to accommodate a growing casino with
# 4,000+ slot machines.
# ★ Optimized the core customer-facing systems by reducing frequent business-
# impacting outages to 99.99% availability.
# ★ Built a high-performance team to install hospitality technology at the new
# casino hotel.
# ★ Engaged with marketing and finance personnel to complete data warehouse
# upgrades and implement business intelligence gaming solutions including
# artificial intelligence for promotional marketing.
# ★ Improved the guest experience by upgrading all mobile and Wi-Fi systems
# across the property.
# ★ Saved millions in operational expenses through strategic contract
# negotiations.
# ★ Contributed significantly to business success by taking over a critical BI and
# data warehousing initiative.
# The Venetian Resort Las Vegas | Las Vegas Sands Corp.
#   Page 5 of 9
# Chief Information Officer
# 2011 - 2013 (2 years)
# Las Vegas, NV
# As Chief Information Officer I oversaw IT operations for the largest five-
# diamond resort in the world. Among other functions, I established and
# maintained positive relations with property executives. I also served an
# interim role as Chief Technology Officer and Chief Information Security
# Officer for several months. Additionally, I managed all data center and
# property infrastructure modernization efforts with a focus on driving technology
# innovation across all business units
# A few key achievements in this role include:
# ★ Transformed the IT organization into an efficient structure aligned with the
# business model.
# ★ Spearheaded the green data center initiative for the business to implement a
# private cloud platform at a secured facility.
# ★ Decreased upgrade outage time for a critical business application from 22
# hours to 12 hours and provided a customized offline solution to implement
# during downtime.
# ★ Decreased operational costs through effective negotiations with a carrier to
# implement a business-wide $25M distributed antenna system (DAS).
# ★ Took over a delayed customer relationship management (CRM) initiative
# through offshore development with an onshore partner to integrate the CRM
# platform with the new cloud operations platform.
# ★ Upgraded the guest Wi-Fi system providing the most cutting-edge Wi-Fi
# center, decreased issue ticket volume by 85%, and significantly increased
# guest experience.
# Las Vegas Sands Corp.
# VP of US IT Operations
# 2011 - 2013 (2 years)
# Las Vegas, Nevada, United States
#   Page 6 of 9
# I started as the VP of Global US IT Operations which was transitioned into the
# role of CIO for the Venetian and Palazzo 5-Diamond Luxury Gaming Resort.
# Please see that Description.
# Apollo Group, Inc. / University of Phoenix
# Vice President of Enterprise Network Services
# 2009 - 2011 (2 years)
# Phoenix, Arizona Area
# As Vice President of Enterprise Network Services I managed the global
# technology infrastructure and team of 100 architects and engineers. Among
# a range of functions I collaborated with the company President and executive
# leaders in developing long-term business strategies. I also supported
# modernization efforts across the infrastructure to accommodate a significant
# overhaul of the student platform including enhanced security, access, and
# media distribution.
# A few key achievements in this role include:
# ★ Successfully led the $80M data center and wide area networks (WANs)
# upgrade.
# ★ Spearheaded the strategic IT contact center transformation project across
# multiple business units.
# ★ Upgraded local area network (LAN) and wireless technology in 120 sites in
# six months, which enhanced student experience and drove up student activity
# by 40%.
# ★ Maximized network availability and performance from 3% to 99.999% for the
# main campus network and call centers.
# ★ Implemented predictive dialer technology and quadrupled the student
# contact rate without a need for extra staff members.
# ★ Decreased costs and increased workforce utilization and customer
# experience visibility by unifying 10 different PBX/ACD systems.
#   Page 7 of 9
# ★ Renegotiated supplier contracts, managed telecommunication expenses,
# and redesigned the network, which saved $8M in annual costs and $40M in
# CapEx.
# Applied Materials
# Senior Director, Project Management Office
# 2006 - 2009 (3 years)
# Austin, TX
# ★ Senior Director, Project Management Office (2009)
# ★ Senior Director, Production Services (2008 – 2009)
# ★ Director, Network and Infrastructure Solutions (2006 – 2008)
# Guided global IS business unit through reorganization into a single supply and
# demand organization. Led global functional and regional delivery directors
# and 450+ full-time staff in overseeing global IT infrastructure and operations.
# Directed operations, methodology, processes and tools improvement for
# technology activities and initiatives. Transformed geographically dispersed
# staff into cohesive virtual teams. Delivered significant improvements to
# customer service quality and cost/energy reductions. Captured $4M in annual
# savings. Built award-winning cross-functional team to monitor the real-time
# status of multiple fab sites worldwide. Reduced annual run rate and saved
# millions of dollars. Implemented global MPLS solution to support changing
# global business model, M&As, and global ERP rollout, saving $1.7M annually.
# DHL
# Director, Global Networking and Communications
# 1999 - 2006 (7 years)
# Scottsdale, AZ
# ★ Director, Global Networking and Communications (2005 – 2006)
# ★ Director, Global IS Telecom Solutions (2004 – 2005)
# ★ Director, Global IS Internet Managed Services (2003 – 2004)
# Defined architectures and technologies supporting acquisitions integration as
# an integral part of long term business strategy. Supervised staff of 17. As a
# member of the Business IT innovation team fostered a culture of exceptional
# business value. Merged three companies into a single global network
# connecting 220+ countries under the DHL brand. Designed/implemented
# a global email security solution that blocked spam messages. Directed full
# migration of global network operations to a more efficient ITIL-based service
# and support model. Strategized seamless integration of $15B acquisition.
#   Page 8 of 9
# Delivered global secure remote access solution, meeting connectivity
# requirements and reducing costs by $250M.
# Danzas
# Director, Security and Communication
# 2001 - 2003 (2 years)
# Merged with DHL in 2003.
# Air Express International (AEI)
# Manager, Mid-Range Systems Development and Networking
# 1999 - 2001 (2 years)
# Darien, CT
# Acquired by Danzas in 2001.
# Education
# Claremont Graduate University
# Certificate, Tribal Administration Program · (2014 - 2015)
# Florida Institute of Technology
# BA, Business Administration, CIS
# Orange County Community College
# Associate's Degree, Business Administration and Management, General
#   Page 9 of 9

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Greg Aldrich"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Greg Aldrich. You are answering questions on Greg Aldrich's website, particularly questions related to Greg Aldrich's career, background, skills and experience. Your responsibility is to represent Greg Aldrich for interactions on the website as faithfully as possible. You are given a summary of Greg Aldrich's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nGreg Aldrich is a global CIO and technology executive with 30+ years driving enterprise-scale transformation, operating model modernization, and large-scale infrastructure strategy across Fortune 500 and complex global environments. Proven success leading M&A integration, cybersecurity governance, enterprise architecture, and technology-enabled business performance — managing teams of 450+ and capital programs exceeding $80M. Adept at aligning fragmented technology portfolios with enterprise strategy, rationalizing vendor ecosystems, and building high-performance IT organizations that deliver sustained competitive advantage.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\ngaldrich@gmail.com\nwww.linkedin.com/in/galdrich\n(LinkedIn)\nTop Skills\nBusiness Transformation\nTechnology Roadmapping\nSolution Architecture\nCertifications\nITIL Foundation Certified 3.0\nPast Certifications: CISSP, NSIAM,\nCCDA, CCNA, CCSE\nMachine Learning\nDigital Transformation\nRobotics: Aerial Robotics\nPublications\nInfoBlox 2013 Global Sales\nConference Customer Keynote\nTelecommuting Has Come of Age\nGlobal GIS Conference (highest\nrated speaker)\nKeynote for Annual Medical\nAssociation Meeting\nCisco Live Customer Panel\nGreg Aldrich\nGlobal CIO | Technology Executive | Aligning IT Strategy with\nBusiness Vision | Driving Digital Transformation & Organizational\nExcellence\nColorado Springs, Colorado, United States\nSummary\nDESIGNING AND DELIVERING TECHNOLOGY SOLUTIONS THAT\nDRIVE ENTERPRISE SUCCESS\nAs a global Technology Executive and Business Leader, I align\nrisk management, security and IT initiatives with business goals to\ndrive enterprise transformation, impacting multiple business lines\nworldwide. \nThrough encouraging collaboration, trust and individual growth,\nI’ve competitively positioned startup, turnaround, and high growth\nenvironments.\nBy implementing process reengineering, change management, and\noutsourcing and insourcing initiatives, I’ve fostered an environment\nof continuous improvement and best practices. \nMy talent for leveraging technology vision and innovation has\ncontributed to my success as an entrepreneurial leader, delivering\nenterprise-wide solutions and driving rapid growth.\nSPECIALTIES\n♦  Technology Leadership\n♦  Strategy Planning and Technology Roadmaps\n♦  Business and Technology Alignment\n♦  Best Practices and Process Re-engineering\n♦  Multibillion Dollar M&As\n♦  Organizational Development and Design\n♦  Global IT Governance, Operations and Security\n♦  Global IT Project / Program Management\n♦  Business and IT Transformation\n♦  Outsourcing and Backsourcing Initiatives\n♦  Global Data Centers\n\xa0 Page 1 of 9\xa0 \xa0\n♦  Cloud Computing\n♦  “Green” Technology Solutions\nExperience\nAndrew Wommack Ministries, Inc.\nChief Information Officer\nAugust 2022\xa0-\xa0Present\xa0(3 years 9 months)\nWoodland Park, Colorado, United States\nAs the Chief Information Officer (CIO) for Andrew Wommack Ministries and\nCharis Bible College, I oversee global IT operations and strategy, ensuring our\ntechnology infrastructure and applications support and enhance our mission\nto spread the Gospel and educate future leaders. As a member of the senior\nleadership team, I collaborate closely with other executives to drive innovation,\nefficiency, and growth across our organization.\nKey Responsibilities\n* Lead the development and implementation of IT strategies ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.5-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I do not currently hold a patent. My expertise and focus have primarily been on driving technology transformation, organizational excellence, and aligning IT strategy with business goals throughout my career. If you have any further questions about my work or experience, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The agent correctly answers that they do not hold a patent, which is consistent with the provided LinkedIn profile and summary. The response also maintains a professional and engaging tone, offering further assistance.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Failed evaluation - retrying
# The agent's response is written in Pig Latin, which is highly unprofessional and inappropriate for a global CIO speaking to a potential client or future employer. The agent should respond in clear, standard English, maintaining a professional and engaging tone.
